# %% [markdown]
# ## The best neighborhood to open cafe shop in Brooklyn, Newyork.

# %%
! pip install geopy
! pip install folium
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.18.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geopy) (1.49)
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/a4/f0/44e69d50519880287cc41e7c8a6acc58daa9a9acf5f6afc52bcc70f69a6d/folium-0.11.0-py2.py3-none-any.whl (93kB)
#      |████████████████████████████████| 102kB 9.3MB/s ta 0:00:011
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/13/fb/9eacc24ba3216510c6b59a4ea1cd53d87f25ba76237d7f4393abeaf4c94e/branca-0.4.1-py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0

# %%
# Importing required libraries.
import pandas as pd
import numpy as np
import requests
import json
from pandas.io.json import json_normalize


import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

from geopy.geocoders import Nominatim

import folium

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %% [markdown]
# We are going to use data provided by NYU Data repository, which is publicly available.

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded')    

with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

neighborhoods_data = newyork_data['features']

# We will convert the json format data to pandas dataframe

column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
neighborhoods = pd.DataFrame(columns=column_names)

for data in neighborhoods_data:
    borough = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

neighborhoods.head()
# Out:
# Data downloaded
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
# filter out the brooklyn neihborhood details
brooklyn_data = neighborhoods[neighborhoods['Borough'] == 'Brooklyn'].reset_index(drop=True)

# %%
address = 'Brooklyn, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 40.6501038, -73.9495823.

# %%
# create map of Manhattan using latitude and longitude values
map_brooklyn = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(brooklyn_data['Latitude'], brooklyn_data['Longitude'], brooklyn_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_brooklyn)  
    
map_brooklyn
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we are going to use FourSquare API to get the neighborhood details

# %%
# Credentials
CLIENT_ID = '#' # your Foursquare ID
CLIENT_SECRET = '#' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: DWZNP5R3T2YNI3OHENZOAIG40FUKXME5301POZITUQ5M52PC
# CLIENT_SECRET:AE22EEPIZJZJEMLICGMLKVKUS2EZMUYJSXDMHWWTMLENGXVO

# %%
search_query = 'Coffee Shops'
radius = 40000
LIMIT = 100
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

resp = requests.get(url).json()

venues = resp['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...     2082742
# 1  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...         NaN
# 4  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...      403612
#
#                 delivery.provider.icon.name  \
# 0  /delivery_provider_seamless_20180129.png
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  /delivery_provider_seamless_20180129.png
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
#
#   delivery.provider.name                                       delivery.url  \
# 0               seamless  https://www.seamless.com/menu/plg-coffee-house...
# 1                    NaN                                                NaN
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4               seamless  https://www.seamless.com/menu/park-side-coffee...
#
#    hasPerk                        id  location.address  ...  \
# 0    False  5389f295498e264f18c5d652    499 Rogers Ave  ...
# 1    False  5b89aecc8c812a002ca7f2af    78 Rockwell Pl  ...
# 2    False  5cf821d8250cab002cfbf4c4         Rogers Av  ...
# 3    False  59b2c702f96b2c7bd7416992               NaN  ...
# 4    False  4c41a4bbaf052d7f079d7d79  188 Parkside Ave  ...
#
#                            location.formattedAddress  \
# 0  [499 Rogers Ave (Midwood St), Brooklyn, NY 112...
# 1  [78 Rockwell Pl, New York, NY 11217, United St...
# 2  [Rogers Av (Midwood St), Brooklyn, NY 11225, U...
# 3                [New York, NY 11210, United States]
# 4  [188 Parkside Ave (at Ocean Ave.), Brooklyn, N...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 40.66000670620193...    40.660007
# 1  [{'label': 'display', 'lat': 40.687751, 'lng':...    40.687751
# 2  [{'label': 'display', 'lat': 40.659725, 'lng':...    40.659725
# 3  [{'label': 'display', 'lat': 40.616927, 'lng':...    40.616927
# 4  [{'label': 'display', 'lat': 40.65508454943389...    40.655085
#
#   location.lng  location.neighborhood location.postalCode location.state  \
# 0   -73.953362                    NaN               11225             NY
# 1   -73.979387                    NaN               11217             NY
# 2   -73.953280                    NaN               11225             NY
# 3   -73.944795                    NaN               11210             NY
# 4   -73.961502                    NaN               11226             NY
#
#                              name    referralId venuePage.id
# 0     PLG Coffee House and Tavern  v-1593626733          NaN
# 1               Coffee Project NY  v-1593626733          NaN
# 2                       Coffee Rx  v-1593626733          NaN
# 3                Coffee Redefined  v-1593626733          NaN
# 4  Parkside Coffee Shop and Diner  v-1593626733          NaN
#
# [5 rows x 25 columns]

# %%
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location')]+['id']
filtered_df = dataframe.loc[:,filtered_columns]

def get_category_type(row):
    try: 
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

filtered_df['categories'] = filtered_df.apply(get_category_type, axis=1)
filtered_df.columns = [column.split('.')[-1] for column in filtered_df.columns]
filtered_df.head()
# Out:
#                              name   categories           address  cc  \
# 0     PLG Coffee House and Tavern         Café    499 Rogers Ave  US
# 1               Coffee Project NY  Coffee Shop    78 Rockwell Pl  US
# 2                       Coffee Rx  Coffee Shop         Rogers Av  US
# 3                Coffee Redefined  Coffee Shop               NaN  US
# 4  Parkside Coffee Shop and Diner        Diner  188 Parkside Ave  US
#
#        city        country    crossStreet  distance  \
# 0  Brooklyn  United States     Midwood St      1147
# 1  New York  United States            NaN      4888
# 2  Brooklyn  United States     Midwood St      1115
# 3  New York  United States            NaN      3715
# 4  Brooklyn  United States  at Ocean Ave.      1149
#
#                                     formattedAddress  \
# 0  [499 Rogers Ave (Midwood St), Brooklyn, NY 112...
# 1  [78 Rockwell Pl, New York, NY 11217, United St...
# 2  [Rogers Av (Midwood St), Brooklyn, NY 11225, U...
# 3                [New York, NY 11210, United States]
# 4  [188 Parkside Ave (at Ocean Ave.), Brooklyn, N...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.66000670620193...  40.660007 -73.953362
# 1  [{'label': 'display', 'lat': 40.687751, 'lng':...  40.687751 -73.979387
# 2  [{'label': 'display', 'lat': 40.659725, 'lng':...  40.659725 -73.953280
# 3  [{'label': 'display', 'lat': 40.616927, 'lng':...  40.616927 -73.944795
# 4  [{'label': 'display', 'lat': 40.65508454943389...  40.655085 -73.961502
#
#   neighborhood postalCode state                        id
# 0          NaN      11225    NY  5389f295498e264f18c5d652
# 1          NaN      11217    NY  5b89aecc8c812a002ca7f2af
# 2          NaN      11225    NY  5cf821d8250cab002cfbf4c4
# 3          NaN      11210    NY  59b2c702f96b2c7bd7416992
# 4          NaN      11226    NY  4c41a4bbaf052d7f079d7d79

# %%
filtered_df = filtered_df[filtered_df['city']=='Brooklyn'].reset_index(drop=True)
filtered_df.head()
# Out:
#                              name        categories            address  cc  \
# 0     PLG Coffee House and Tavern              Café     499 Rogers Ave  US
# 1                       Coffee Rx       Coffee Shop          Rogers Av  US
# 2  Parkside Coffee Shop and Diner             Diner   188 Parkside Ave  US
# 3               Ciao Bella Coffee       Coffee Shop  284 Clarkson Ave.  US
# 4   Caoba Restaurant/ Coffee Shop  Cuban Restaurant   762 Snediker Ave  US
#
#        city        country    crossStreet  distance  \
# 0  Brooklyn  United States     Midwood St      1147
# 1  Brooklyn  United States     Midwood St      1115
# 2  Brooklyn  United States  at Ocean Ave.      1149
# 3  Brooklyn  United States  Nostrand Ave.       583
# 4  Brooklyn  United States            NaN      4431
#
#                                     formattedAddress  \
# 0  [499 Rogers Ave (Midwood St), Brooklyn, NY 112...
# 1  [Rogers Av (Midwood St), Brooklyn, NY 11225, U...
# 2  [188 Parkside Ave (at Ocean Ave.), Brooklyn, N...
# 3  [284 Clarkson Ave. (Nostrand Ave.), Brooklyn, ...
# 4  [762 Snediker Ave, Brooklyn, NY 11207, United ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.66000670620193...  40.660007 -73.953362
# 1  [{'label': 'display', 'lat': 40.659725, 'lng':...  40.659725 -73.953280
# 2  [{'label': 'display', 'lat': 40.65508454943389...  40.655085 -73.961502
# 3  [{'label': 'display', 'lat': 40.65530776977539...  40.655308 -73.950455
# 4  [{'label': 'display', 'lat': 40.65608819435355...  40.656088 -73.897702
#
#     neighborhood postalCode state                        id
# 0            NaN      11225    NY  5389f295498e264f18c5d652
# 1            NaN      11225    NY  5cf821d8250cab002cfbf4c4
# 2            NaN      11226    NY  4c41a4bbaf052d7f079d7d79
# 3            NaN      11226    NY  5e665bb9acf4e7000855c560
# 4  East New York      11207    NY  542da088498e60c8dafa5b06

# %% [markdown]
# Lets see the coffee shops in the brokklyn map to get more ideas

# %%
cafe_map = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(filtered_df.lat, filtered_df.lng, filtered_df.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='yellow',
        fill_opacity = 1.0
    ).add_to(cafe_map)

cafe_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Lets Cluster the neighbourhood to get more insights

# %%
X = filtered_df.values[:,10:12]
X = np.nan_to_num(X)
clust_data = StandardScaler().fit_transform(X)
clust_data
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([[-0.79061557,  0.25946817],
#        [-0.80150969,  0.26269084],
#        [-0.98096479, -0.06066852],
#        [-0.97233243,  0.37380894],
#        [-0.94215192,  2.4485711 ],
#        [ 0.02618661, -1.4381804 ],
#        [-1.13153579,  0.52856048],
#        [-1.30668088, -0.42302471],
#        [-1.73599838, -2.59987951],
#        [ 0.32835771, -1.26570105],
#        [-0.97425281, -0.00533332],
#        [-0.38094782, -0.72756402],
#        [-1.37226844,  0.45155268],
#        [ 1.38093968,  0.01687942],
#        [ 0.52215726, -0.07753311],
#        [ 0.36097244, -0.21324547],
#        [ 1.32546177,  0.11470907],
#        [ 1.45256006,  0.03088084],
#        [ 0.02224999, -0.66966285],
#        [-0.56538815,  1.96550257],
#        [ 0.12151236, -1.39020711],
#        [ 1.64823534,  0.61226415],
#        [ 1.34487272,  0.60838543],
#        [-0.2820876 , -0.38431241],
#        [ 0.50432948, -0.23734699],
#        [ 1.03845517,  0.23959905],
#        [ 0.89765107,  1.66707907],
#        [ 1.26279262, -0.08729233]])

# %%
k = 3

kmeans = KMeans(init='k-means++', n_clusters=k, random_state=4)
kmeans.fit(clust_data)
kmeans.labels_
# Out:
# array([2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 1, 2, 0, 0, 0, 0, 0, 1, 2, 1, 0,
#        0, 1, 0, 0, 0, 0], dtype=int32)

# %%
labels = kmeans.labels_
filtered_df['Cluster labels'] = labels
filtered_df.head()
# Out:
#                              name        categories            address  cc  \
# 0     PLG Coffee House and Tavern              Café     499 Rogers Ave  US
# 1                       Coffee Rx       Coffee Shop          Rogers Av  US
# 2  Parkside Coffee Shop and Diner             Diner   188 Parkside Ave  US
# 3               Ciao Bella Coffee       Coffee Shop  284 Clarkson Ave.  US
# 4   Caoba Restaurant/ Coffee Shop  Cuban Restaurant   762 Snediker Ave  US
#
#        city        country    crossStreet  distance  \
# 0  Brooklyn  United States     Midwood St      1147
# 1  Brooklyn  United States     Midwood St      1115
# 2  Brooklyn  United States  at Ocean Ave.      1149
# 3  Brooklyn  United States  Nostrand Ave.       583
# 4  Brooklyn  United States            NaN      4431
#
#                                     formattedAddress  \
# 0  [499 Rogers Ave (Midwood St), Brooklyn, NY 112...
# 1  [Rogers Av (Midwood St), Brooklyn, NY 11225, U...
# 2  [188 Parkside Ave (at Ocean Ave.), Brooklyn, N...
# 3  [284 Clarkson Ave. (Nostrand Ave.), Brooklyn, ...
# 4  [762 Snediker Ave, Brooklyn, NY 11207, United ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.66000670620193...  40.660007 -73.953362
# 1  [{'label': 'display', 'lat': 40.659725, 'lng':...  40.659725 -73.953280
# 2  [{'label': 'display', 'lat': 40.65508454943389...  40.655085 -73.961502
# 3  [{'label': 'display', 'lat': 40.65530776977539...  40.655308 -73.950455
# 4  [{'label': 'display', 'lat': 40.65608819435355...  40.656088 -73.897702
#
#     neighborhood postalCode state                        id  Cluster labels
# 0            NaN      11225    NY  5389f295498e264f18c5d652               2
# 1            NaN      11225    NY  5cf821d8250cab002cfbf4c4               2
# 2            NaN      11226    NY  4c41a4bbaf052d7f079d7d79               2
# 3            NaN      11226    NY  5e665bb9acf4e7000855c560               2
# 4  East New York      11207    NY  542da088498e60c8dafa5b06               2

# %% [markdown]
# #### Lets see the clustered neighborhood on map

# %%
cluster_map = folium.Map(location =[latitude, longitude], zoom_start=11)


colors_array = cm.rainbow(np.linspace(0, 1, k))
rainbow = [colors.rgb2hex(i) for i in colors_array]

for lat, lng, cluster in zip(filtered_df['lat'], filtered_df['lng'], filtered_df['Cluster labels']):
    folium.CircleMarker(
        [lat,lng],
    radius = 5,
    color = rainbow[cluster-1],
    popup=cluster,
    fill= True,
    fill_color=rainbow[cluster-1],
    fill_opacity = 0.7).add_to(cluster_map)

cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# In the above map we can see all coffee shops has been disturbuted in Brokklyn brorugh.
#
# Cluster 0 : williamsburg
#
# Cluster 1 : Caroll Gardens
#
# Cluster 2 : East new york

# %% [markdown]
# ### Finding the numbers of coffee shops in clusters

# %%
filtered_df.groupby('Cluster labels')['Cluster labels'].count()
# Out:
# Cluster labels
# 0    11
# 1     7
# 2    10
# Name: Cluster labels, dtype: int64

# %% [markdown]
# ## Findings

# %% [markdown]
# The best option would be to open coffee shop on cluster 1 area (i.e. Caroll gardens) as this area has less numbers of coffee shops. As there is less number of coffee shops in this cluster than others but not that less which states that the customers count is very low. Also less number of coffee shop suggests that it will be less competitive for the shop owner than other clusters.
